# %% [markdown]
# ### This notebook contains all the cleaning operations done on parsed dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/parsed/pune/listings_cleaned.csv")

# %%
df.head()
# Out:
#    price_raw   price_num                                            bhk_raw  \
# 0   ₹ 65 Lac   6500000.0               2 BHK Flat for Sale in Dhanori, Pune
# 1   ₹ 70 Lac   7000000.0  2 BHK Flat for Sale in Ravet, Pimpri Chinchwad...
# 2   ₹ 25 Lac   2500000.0      Studio Apartment for Sale in Dhankawadi, Pune
# 3  ₹ 1.35 Cr  13500000.0      3 BHK Flat for Sale in Bhugaon, Bavdhan, Pune
# 4   ₹ 50 Lac   5000000.0          2 BHK Flat for Sale in Tingre Nagar, Pune
#
#    bhk_number               area_raw  area_sqft      locality  city  \
# 0         2.0   Carpet Area 834 sqft      834.0       Dhanori  Pune
# 1         2.0   Carpet Area 800 sqft      800.0         Ravet  Pune
# 2         NaN    Super Area 400 sqft      400.0    Dhankawadi  Pune
# 3         3.0  Carpet Area 1160 sqft     1160.0       Bhugaon  Pune
# 4         2.0   Carpet Area 715 sqft      715.0  Tingre Nagar  Pune
#
#                                          listing_url
# 0  https://www.magicbricks.com/bramha-sky-city-ph...
# 1  https://www.magicbricks.com/lotus-laxmi-ravet-...
# 2  https://www.magicbricks.com/propertyDetails/40...
# 3  https://www.magicbricks.com/propertyDetails/3-...
# 4  https://www.magicbricks.com/choice-group-goodw...

# %% [markdown]
# ### Detecting and removing duplicates

# %%
# List Columns
df.columns.tolist()
# Out:
# ['price_raw',
#  'price_num',
#  'bhk_raw',
#  'bhk_number',
#  'area_raw',
#  'area_sqft',
#  'locality',
#  'city',
#  'listing_url']

# %%
print("Before length:", len(df))
# Out:
# Before length: 3000

# %%
# Columns based on we are going to look up
dup_cols = ['listing_url', 'price_num', 'area_sqft']

duplicates = df[df.duplicated(subset=dup_cols, keep='first')].sort_values(by=dup_cols)

# Display how many duplicates found
print("Duplicate rows found:", duplicates.shape[0])
print(duplicates.head())
# Out:
# Duplicate rows found: 82
#       price_raw   price_num  \
# 2826   ₹ 42 Lac   4200000.0
# 314   ₹ 2.42 Cr  24200000.0
# 308   ₹ 2.62 Cr  26200000.0
# 307   ₹ 2.85 Cr  28500000.0
# 1520  ₹ 3.50 Cr  35000000.0
#
#                                                 bhk_raw  bhk_number  \
# 2826                2 BHK Flat for Sale in Katraj, Pune         2.0
# 314      3 BHK Flat for Sale in Amanora Park Town, Pune         3.0
# 308      3 BHK Flat for Sale in Amanora Park Town, Pune         3.0
# 307      3 BHK Flat for Sale in Amanora Park Town, Pune         3.0
# 1520  3 BHK Flat for Sale in Sahakar Nagar Parvati P...         3.0
#
#                    area_raw  area_sqft                      locality  city  \
# 2826    Super Area 881 sqft      881.0                        Katraj  Pune
# 314   Carpet Area 1232 sqft     1232.0             Amanora Park Town  Pune
# 308   Carpet Area 1340 sqft     1340.0             Amanora Park Town  Pune
# 307   Carpet Area 1460 sqft     1460.0             Amanora Park Town  Pune
# 1520  Carpet Area 1610 sqft     1610.0  Sahakar Nagar Parvati Paytha  Pune
#
#                                             listing_url
# 2826  https://www.magicbricks.com/acme-arcadia-katra...
# 314   https://www.magicbricks.com/amanora-gateway-to...
# 308   https://www.magicbricks.com/amanora-gateway-to...
# 307   https://www.magicbricks.com/amanora-gateway-to...
# 1520  https://www.magicbricks.com/amits-montecito-sa...

# %%
# Save duplicates to file
duplicates.to_csv("../../data/logs/duplicates_removed.csv", index=False)
print("Saved duplicate rows to logs/duplicates_removed.csv")
# Out:
# Saved duplicate rows to logs/duplicates_removed.csv

# %%
# Drop duplicates
df_cleaned = df.drop_duplicates(subset=dup_cols, keep='first')
print("Rows after duplicate removal:", df_cleaned.shape[0])
# Out:
# Rows after duplicate removal: 2918

# %%
#Saving to new file
df_cleaned.to_csv("../../data/parsed/pune/unique_listing.csv", index=False)

# %% [markdown]
# ### Handling 'call For price'

# %%
# Change dataframe first to our newly created csv
df = pd.read_csv("../../data/parsed/pune/unique_listing.csv")

# %%
df['price_raw'].sample(20)
# Out:
# 2662          ₹ 15 Lac
# 819           ₹ 80 Lac
# 1019    Call for Price
# 802         ₹ 78.7 Lac
# 6            ₹ 1.20 Cr
# 2312         ₹ 3.60 Cr
# 1214          ₹ 78 Lac
# 140           ₹ 99 Lac
# 279          ₹ 2.42 Cr
# 1804          ₹ 25 Lac
# 2542         ₹ 2.50 Cr
# 1391          ₹ 52 Lac
# 386           ₹ 53 Lac
# 613          ₹ 2.88 Cr
# 817           ₹ 72 Lac
# 2614        ₹ 71.5 Lac
# 783           ₹ 50 Lac
# 1964         ₹ 1.14 Cr
# 226           ₹ 15 Lac
# 228          ₹ 2.11 Cr
# Name: price_raw, dtype: object

# %%
# mask for call for price
mask_call_for_price = df['price_raw'].str.lower().str.contains("call for price", na=False)
df[mask_call_for_price].head()
# Out:
#           price_raw  price_num  \
# 54   Call for Price        NaN
# 57   Call for Price        NaN
# 73   Call for Price        NaN
# 91   Call for Price        NaN
# 118  Call for Price        NaN
#
#                                                bhk_raw  bhk_number  \
# 54             1 BHK Flat for Sale in Manjari BK, Pune         1.0
# 57                  3 BHK Flat for Sale in Baner, Pune         3.0
# 73   1 BHK Flat for Sale in Bhairavnath Nagar Kirka...         1.0
# 91                 Apartment for Sale in Shivane, Pune         NaN
# 118              1 BHK Flat for Sale in Balewadi, Pune         1.0
#
#                   area_raw  area_sqft                      locality  city  \
# 54    Carpet Area 450 sqft      450.0                    Manjari BK  Pune
# 57   Carpet Area 1213 sqft     1213.0                         Baner  Pune
# 73                     NaN        NaN  Bhairavnath Nagar Kirkatwadi  Pune
# 91     Super Area 632 sqft      632.0                       Shivane  Pune
# 118   Carpet Area 491 sqft      491.0                      Balewadi  Pune
#
#                                            listing_url
# 54   https://www.magicbricks.com/gemini-grand-bay-m...
# 57   https://www.magicbricks.com/nyati-emerald-bane...
# 73   https://www.magicbricks.com/propertyDetails/1-...
# 91   https://www.magicbricks.com/bhagwant-rahi-resi...
# 118  https://www.magicbricks.com/avishkar-pavilion-...

# %%
print("Rows with 'Call for Price':", mask_call_for_price.sum())
# Out:
# Rows with 'Call for Price': 92

# %%
# Save to file
df[mask_call_for_price].to_csv("../../data/logs/call_for_price_removed.csv", index=False)

# %%
# Drop "Call for price rows"
df = df[~df['price_raw'].str.lower().str.contains("call for price", na=False)]

# %%
print((df['price_raw'].str.lower().str.contains("call for price", na=False)).sum())
# Out:
# 0

# %% [markdown]
# ### Validationg 'price_num' column

# %%
#listing out samples
df['price_num'].sample(20)
# Out:
# 1102     4800000.0
# 2117    12000000.0
# 2806     7100000.0
# 1202     9370000.0
# 1161     6700000.0
# 1153     8370000.0
# 580     20900000.0
# 315     22500000.0
# 2761     8960000.0
# 1952    47400000.0
# 1142    10700000.0
# 2190     5660000.0
# 793      4200000.0
# 2291    10000000.0
# 740     24000000.0
# 2239    10500000.0
# 1554    20800000.0
# 2874     2200000.0
# 1870    15200000.0
# 789      6800000.0
# Name: price_num, dtype: float64

# %%
#finding null values
print(df['price_num'].isna().sum())
# Out:
# 0

# %%
# are there any negative values
df[df['price_num'] <= 0]
# Out:
# Empty DataFrame
# Columns: [price_raw, price_num, bhk_raw, bhk_number, area_raw, area_sqft, locality, city, listing_url]
# Index: []

# %%
df['price_num'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Validating 'bhk_number' column

# %%
df['bhk_number'].sample(10)
# Out:
# 2459    1.0
# 2665    1.0
# 347     3.0
# 1503    2.0
# 315     3.0
# 1687    2.0
# 2471    3.0
# 843     3.0
# 26      1.0
# 1483    2.0
# Name: bhk_number, dtype: float64

# %%
print(df['bhk_number'].isna().sum())
# Out:
# 16

# %%
bhk_na = df[df['bhk_number'].isna()]
bhk_na
# Out:
#        price_raw  price_num  \
# 2       ₹ 25 Lac  2500000.0
# 106      ₹ 3 Lac   300000.0
# 178     ₹ 25 Lac  2500000.0
# 192     ₹ 18 Lac  1800000.0
# 325     ₹ 27 Lac  2700000.0
# 592     ₹ 18 Lac  1800000.0
# 607   ₹ 13.5 Lac  1350000.0
# 1191    ₹ 12 Lac  1200000.0
# 1301    ₹ 13 Lac  1300000.0
# 1570  ₹ 63.2 Lac  6320000.0
# 1571  ₹ 53.5 Lac  5350000.0
# 2101    ₹ 17 Lac  1700000.0
# 2590    ₹ 25 Lac  2500000.0
# 2728  ₹ 94.5 Lac  9450000.0
# 2880     ₹ 8 Lac   800000.0
# 2883    ₹ 55 Lac  5500000.0
#
#                                                 bhk_raw  bhk_number  \
# 2         Studio Apartment for Sale in Dhankawadi, Pune         NaN
# 106    Studio Apartment for Sale in Wadgaon Sheri, Pune         NaN
# 178        Studio Apartment for Sale in Bibwewadi, Pune         NaN
# 192         Studio Apartment for Sale in Fursungi, Pune         NaN
# 325            Studio Apartment for Sale in Aundh, Pune         NaN
# 592   Studio Apartment for Sale in Kamshet Gaothan, ...         NaN
# 607   Studio Apartment for Sale in Talegaon Dabhade,...         NaN
# 1191  Studio Apartment for Sale in Keshav Nagar Mund...         NaN
# 1301         Studio Apartment for Sale in Vadgaon, Pune         NaN
# 1570     Studio Apartment for Sale in Viman Nagar, Pune         NaN
# 1571     Studio Apartment for Sale in Viman Nagar, Pune         NaN
# 2101          Studio Apartment for Sale in Chakan, Pune         NaN
# 2590       Studio Apartment for Sale in Hinjawadi, Pune         NaN
# 2728               Apartment for Sale in Wanowrie, Pune         NaN
# 2880        Studio Apartment for Sale in Hadapsar, Pune         NaN
# 2883  Studio Apartment for Sale in Amanora Park Town...         NaN
#
#                   area_raw  area_sqft              locality  city  \
# 2      Super Area 400 sqft      400.0            Dhankawadi  Pune
# 106   Carpet Area 200 sqft      200.0         Wadgaon Sheri  Pune
# 178    Super Area 375 sqft      375.0             Bibwewadi  Pune
# 192    Super Area 398 sqft      398.0              Fursungi  Pune
# 325    Super Area 368 sqft      368.0                 Aundh  Pune
# 592    Super Area 495 sqft      495.0       Kamshet Gaothan  Pune
# 607    Super Area 350 sqft      350.0      Talegaon Dabhade  Pune
# 1191   Super Area 281 sqft      281.0  Keshav Nagar Mundhwa  Pune
# 1301   Super Area 330 sqft      330.0               Vadgaon  Pune
# 1570  Carpet Area 406 sqft      406.0           Viman Nagar  Pune
# 1571  Carpet Area 337 sqft      337.0           Viman Nagar  Pune
# 2101   Super Area 250 sqft      250.0                Chakan  Pune
# 2590   Super Area 180 sqft      180.0             Hinjawadi  Pune
# 2728  Super Area 1040 sqft     1040.0              Wanowrie  Pune
# 2880   Super Area 300 sqft      300.0              Hadapsar  Pune
# 2883  Carpet Area 448 sqft      448.0     Amanora Park Town  Pune
#
#                                             listing_url
# 2     https://www.magicbricks.com/propertyDetails/40...
# 106   https://www.magicbricks.com/bramha-corp-smart-...
# 178   https://www.magicbricks.com/propertyDetails/37...
# 192   https://www.magicbricks.com/sanjuda-complex-ph...
# 325   https://www.magicbricks.com/propertyDetails/36...
# 592   https://www.magicbricks.com/propertyDetails/49...
# 607   https://www.magicbricks.com/propertyDetails/35...
# 1191  https://www.magicbricks.com/propertyDetails/28...
# 1301  https://www.magicbricks.com/propertyDetails/33...
# 1570  https://www.magicbricks.com/horizon-neon-viman...
# 1571  https://www.magicbricks.com/horizon-neon-viman...
# 2101  https://www.magicbricks.com/eiffel-city-chakan...
# 2590  https://www.magicbricks.com/propertyDetails/18...
# 2728  https://www.magicbricks.com/propertyDetails/10...
# 2880  https://www.magicbricks.com/propertyDetails/30...
# 2883  https://www.magicbricks.com/amanora-adreno-tow...

# %%
# Converting Nan to 1
mask_studio = df['bhk_raw'].str.contains("Studio Apartment", case=False, na=False)
df.loc[mask_studio, 'bhk_number'] = 1

# %%
bhk_na = df[df['bhk_number'].isna()]
bhk_na
# Out:
#        price_raw  price_num                               bhk_raw  bhk_number  \
# 2728  ₹ 94.5 Lac  9450000.0  Apartment for Sale in Wanowrie, Pune         NaN
#
#                   area_raw  area_sqft  locality  city  \
# 2728  Super Area 1040 sqft     1040.0  Wanowrie  Pune
#
#                                             listing_url
# 2728  https://www.magicbricks.com/propertyDetails/10...

# %%
#inspect this 
df.loc[2728]
# Out:
# price_raw                                             ₹ 94.5 Lac
# price_num                                              9450000.0
# bhk_raw                     Apartment for Sale in Wanowrie, Pune
# bhk_number                                                   NaN
# area_raw                                    Super Area 1040 sqft
# area_sqft                                                 1040.0
# locality                                                Wanowrie
# city                                                        Pune
# listing_url    https://www.magicbricks.com/propertyDetails/10...
# Name: 2728, dtype: object

# %%
# Drop this we could not infer what will be the bhk
df = df.dropna(subset=['bhk_number'])

# %%
df[df['bhk_number'].isna()]
# Out:
# Empty DataFrame
# Columns: [price_raw, price_num, bhk_raw, bhk_number, area_raw, area_sqft, locality, city, listing_url]
# Index: []
